# %% [markdown]
# ## START

# %% [markdown]
# ### Корпус текстов

# %% [markdown]
# Сгенерировал по описанию клиентов поздравления с помощтю ChatGPT4o, GigaChat Max, GigaChat Max 2, DeepSeak V1, DeepSeek R1 и YandexGPT
#
#
# **Промпт:**
#
# Напиши персонализированное поздравление клиенту банка. Поздравление должно быть яркое, запоминающееся и не должно оскорблять клиента. Также нельзя писать фразы, которые можно понять не правильно или есть двусмысленный подтекст.
#
# Оформление: не более 400 символов. 2-3 предложения. Пример структуры поздравления:
# 'С днём рождения!
#
# Екатерина Васильевна!
#
# Пусть вам всегда открываются новые двери, а яркий свет успеха пробивается в каждое окно. Желаем процветания и ярких впечатлений!
#
# Ваш клиентский менеджер
# [ФИО менеджера]'
#
# Описание клиента:

# %%
discriptions = ["""ФИО: Иванов Алексей Сергеевич
Возраст: 34 года
Гендер: Мужчина
Семейное положение: Женат
Должность: Руководитель отдела разработки
Компания: ООО "ТехноИнновации"

Личные предпочтения:
Алексей — увлеченный профессионал в сфере IT, ценит современные технологии и стремится к постоянному саморазвитию. В свободное время занимается спортом, предпочитает бег и велосипедные прогулки. Любит читать научную фантастику и книги по психологии. В питании придерживается принципов здорового образа жизни, но иногда позволяет себе побаловаться домашней выпечкой. Обожает путешествовать с семьей, особенно в горные регионы. В работе ценит командный дух и инновационные подходы.""",
                """ФИО: Смирнова Анна Дмитриевна
Возраст: 28 лет
Гендер: Женщина
Семейное положение: Не замужем
Должность: Маркетолог-аналитик
Компания: ЗАО "МедиаГрупп"

Личные предпочтения:
Анна — творческая и амбициозная личность, которая умеет находить нестандартные решения в работе. Она обожает изучать новые тренды в digital-маркетинге и активно ведет блог о маркетинговых стратегиях. В свободное время занимается йогой и увлекается фотографией, особенно любит снимать природу и городские пейзажи. Предпочитает здоровое питание, но не откажется от чашки хорошего кофе с десертом. Анна любит проводить время с друзьями, посещать выставки и кино. В работе ценит четкость, креатив и возможность реализовывать свои идеи.""",
                """ФИО: Петров Денис Игоревич
Возраст: 42 года
Гендер: Мужчина
Семейное положение: Разведен
Должность: Финансовый директор
Компания: ПАО "СтройИнвест"

Личные предпочтения:
Денис — серьезный и ответственный человек с аналитическим складом ума. Он увлекается инвестициями и следит за мировыми экономическими трендами. В свободное время играет в шахматы и занимается плаванием. Любит классическую литературу и документальные фильмы. В еде предпочитает блюда европейской кухни, особенно пасту и морепродукты. Денис ценит уединение, но с удовольствием проводит время с близкими друзьями, обсуждая последние новости и делясь опытом. В работе для него важны стабильность, порядок и долгосрочные перспективы.""",
                """ФИО: Козлова Елена Владимировна
Возраст: 31 год
Гендер: Женщина
Семейное положение: Замужем, есть ребенок
Должность: Дизайнер интерьеров
Компания: Студия дизайна "АртПространство"

Личные предпочтения:
Елена — талантливый дизайнер с тонким чувством стиля и любовью к минимализму. Она обожает создавать уютные и функциональные пространства для своих клиентов. В свободное время занимается садоводством и рукоделием, особенно любит вязать. Елена — сторонница здорового образа жизни, предпочитает свежие овощи и фрукты, но иногда балует себя шоколадом. Она любит проводить время с семьей, часто выбирается на природу или в театры. В работе ценит креативность, внимание к деталям и возможность воплощать свои идеи в жизнь.""",

               """ФИО: Тарасов Олег Тимофеевич
Возраст: 29 лет
Гендер: Мужчина
Семейное положение: Холост
Должность: Frontend-разработчик
Компания: IT-компания "CodeCraft"

Личные предпочтения:
Олег — талантливый и увлеченный программист, который живет технологиями и постоянно изучает новые фреймворки и языки программирования. В свободное время он увлекается киберспортом и участвует в локальных турнирах по Dota 2. Также Олег любит читать комиксы и смотреть научно-фантастические сериалы. В еде предпочитает бургеры и пиццу, но старается иногда готовить дома, экспериментируя с рецептами. Олег — интроверт, ценит время наедине с собой, но с удовольствием проводит вечера с друзьями за настольными играми. В работе для него важны интересные задачи, гибкий график и возможность работать удаленно.""",

"""ФИО: Морозова Виктория Андреевна
Возраст: 36 лет
Гендер: Женщина
Семейное положение: В отношениях
Должность: HR-менеджер
Компания: Корпорация "FutureTech"

Личные предпочтения:
Виктория — коммуникабельный и empathetic человек, который любит помогать людям находить свое место в профессии. Она увлекается психологией и часто посещает тренинги по личностному росту. В свободное время занимается танцами (особенно сальсой) и любит готовить, экспериментируя с блюдами азиатской кухни. Виктория обожает путешествовать, особенно в теплые страны, где можно насладиться морем и солнцем. В работе она ценит командную атмосферу, возможность вдохновлять других и видеть результаты своих усилий.""",

"""ФИО: Гришин Артем Павлович
Возраст: 45 лет
Гендер: Мужчина
Семейное положение: Женат, двое детей
Должность: Владелец ресторанного бизнеса
Компания: Сеть ресторанов "ГурманЪ"

Личные предпочтения:
Артем — харизматичный и предприимчивый человек, который превратил свою любовь к кулинарии в успешный бизнес. Он обожает пробовать новые блюда и напитки, а также лично контролирует меню своих ресторанов. В свободное время занимается охотой и рыбалкой, а также коллекционирует редкие вина. Артем — семьянин, любит проводить время с женой и детьми, часто устраивает семейные выезды на природу. В работе для него важны качество, гостеприимство и создание уникального опыта для гостей."""]

# %%
# эталоны
chatgpt = ["""С днём рождения, Алексей Сергеевич!

Пусть новые технологии вдохновляют вас на яркие идеи, а каждый день приносит успехи и открытия! Желаем вам энергии для покорения новых вершин — и в карьере, и в путешествиях. Счастья вам, крепкого здоровья и радости в кругу семьи!

Ваш клиентский менеджер
[ФИО менеджера]""",
              """С днём рождения, Анна Дмитриевна!

Пусть каждый день наполняется вдохновением, яркими кадрами и креативными идеями! Желаем вам интересных проектов, захватывающих открытий и времени для любимых увлечений. Пусть чашка ароматного кофе всегда сопровождает ваши успехи!

Ваш клиентский менеджер
[ФИО менеджера]""",
              """С днём рождения, Денис Игоревич!

Пусть каждое ваше решение ведёт к успеху, а жизнь дарит стабильность, гармонию и новые перспективы! Желаем вам блестящих побед — в финансах, спорте и шахматных партиях. Пусть вас всегда окружают надёжные партнёры и верные друзья!

Ваш клиентский менеджер
[ФИО менеджера]""",
              """С днём рождения, Елена Владимировна!

Пусть ваша жизнь будет такой же гармоничной и вдохновляющей, как созданные вами интерьеры! Желаем вам ярких идей, уюта в доме и радостных моментов с семьёй. Пусть каждый день приносит вам новые открытия и тёплые впечатления!

Ваш клиентский менеджер
[ФИО менеджера]""",
              """**С днём рождения, Олег Тимофеевич!**

Пусть код компилируется без ошибок, а жизнь приносит яркие победы — и в проектах, и на турнирах! Желаем вам нескончаемого потока вдохновения, интересных задач и времени на всё, что приносит удовольствие. Пусть каждый день будет как удачная сборка!

**Ваш клиентский менеджер**
[ФИО менеджера]""",
              """**С днём рождения, Виктория Андреевна!**

Пусть жизнь дарит вдохновение, яркие эмоции и новые путешествия! Желаем вам гармонии, успехов и тепла — как в работе, так и на солнечных побережьях. Пусть каждый день будет наполнен танцем радости и вкусом ярких открытий!

**Ваш клиентский менеджер**
[ФИО менеджера]""",
              """**С днём рождения, Артем Павлович!**

Пусть каждый день приносит новые гастрономические открытия, удачную рыбалку и тёплые моменты в кругу семьи! Желаем вам процветания, вдохновения и ярких вкусовых впечатлений. Пусть ваш бизнес растёт, а жизнь будет наполнена счастьем и успехом!

**Ваш клиентский менеджер**
[ФИО менеджера]"""]

# Список сгенерированных текстов
giga_chat = ["""С днём рождения!

Иванов Алексей Сергеевич!

Желаем вам новых горизонтов в мире технологий и личного роста, как в карьере, так и в увлекательных путешествиях. Пусть каждый день будет наполнен энергией и яркими успехами!

Ваш клиентский менеджер[ФИО менеджера]""",
             """С днём рождения!

Анна Дмитриевна,

Желаем вам креативных идей, вдохновения и новых горизонтов! Пусть каждый день будет наполнен яркими успехами и незабываемыми впечатлениями. Счастья и благополучия!

Ваш клиентский менеджер[ФИО менеджера]""",
             """С днём рождения!

Денис Игоревич,

Желаем вам финансовой стабильности, новых инвестиционных возможностей и успехов во всех начинаниях! Пусть каждый ваш день будет полон гармонии и удовлетворения. Здоровья и благополучия!

Ваш клиентский менеджер[ФИО менеджера]""",
             """С днём рождения!

Елена Владимировна,

Желаем вам вдохновения для новых творческих проектов, гармонии в семье и личного счастья! Пусть ваша жизнь будет такой же яркой и уютной, как ваши интерьеры. Успехов и благополучия!

Ваш клиентский менеджер[ФИО менеджера]""",
             """С днём рождения!

Олег Тимофеевич,

Желаем вам успешных кодов, захватывающих проектов и бесконечного потока креативных идей! Пусть каждый день приносит радость и новые достижения. Здоровья и удачи!

Ваш клиентский менеджер[ФИО менеджера]""",
             """С днём рождения!

Виктория Андреевна,

Желаем вам профессионального роста, вдохновения и гармонии в личной жизни! Пусть каждый день приносит радость общения и новые возможности для самореализации. Счастья и благополучия!

Ваш клиентский менеджер[ФИО менеджера]""",
             """С днём рождения!

Артем Павлович,

Желаем вам гастрономического вдохновения, успешного развития вашего дела и теплых моментов в кругу семьи! Пусть ваше мастерство продолжает радовать гостей, а личные достижения приносят удовлетворение. Здоровья и благополучия!

Ваш клиентский менеджер[ФИО менеджера]"""]


deepseek_v1 = ["""С днём рождения, Алексей Сергеевич!

Пусть ваши идеи, как горные вершины, ведут к новым высотам, а каждый день приносит вдохновение и радость! Желаем вам ярких проектов, крепкого здоровья и незабываемых путешествий с семьёй!

Ваш клиентский менеджер
[ФИО менеджера]""",
            """С днём рождения, Анна Дмитриевна!

Пусть ваши идеи, как яркие кадры, вдохновляют окружающих, а каждый день приносит новые возможности для творчества и роста! Желаем вам лёгкости в достижении целей, вдохновения для блога и прекрасных моментов с друзьями!

Ваш клиентский менеджер
[ФИО менеджера]""",
            """С днём рождения, Денис Игоревич!

Пусть ваши решения, как шахматные ходы, ведут к уверенным победам, а каждый день приносит стабильность и новые возможности для роста! Желаем вам мудрости в инвестициях, вдохновения для новых стратегий и приятных моментов в кругу друзей!

Ваш клиентский менеджер
[ФИО менеджера]""",
            """С днём рождения, Елена Владимировна!

Пусть ваши проекты, как уютный дом, наполняются гармонией и вдохновением, а каждый день приносит радость творчества и теплые моменты с семьёй! Желаем вам ярких идей, уюта в доме и новых успехов в любимом деле!

Ваш клиентский менеджер
[ФИО менеджера]""",
            """С днём рождения, Олег Тимофеевич!

Пусть ваш код всегда работает без багов, а каждый день приносит новые интересные задачи и вдохновение для творчества! Желаем вам побед в киберспорте, увлекательных проектов и приятных вечеров за настольными играми с друзьями!

Ваш клиентский менеджер
[ФИО менеджера]""",
            """С днём рождения, Виктория Андреевна!

Пусть ваши дни наполняются яркими эмоциями, как зажигательная сальса, а каждый проект приносит радость и вдохновение! Желаем вам теплых путешествий, гармонии в жизни и новых успехов в помощи другим!

Ваш клиентский менеджер
[ФИО менеджера]""",
            """С днём рождения, Артем Павлович!

Пусть ваши рестораны, как и ваша жизнь, наполняются изысканными вкусами, теплом и радостью! Желаем вам новых кулинарных шедевров, вдохновения для бизнеса и счастливых моментов в кругу семьи!

Ваш клиентский менеджер
[ФИО менеджера]"""]

deepseek_r1 = ["""С днём рождения!
Алексей Сергеевич!

Пусть ваши IT-проекты, как горные вершины, покоряются легко, а семья наполняет жизнь яркими путешествиями! Желаем энергии для новых спортивных рекордов, вдохновения в книгах и прорывных идей в работе!

Ваш клиентский менеджер
[ФИО менеджера]""",
               """С днём рождения!
Анна Дмитриевна!

Пусть ваши идеи, как яркие кадры городских пейзажей, вдохновляют аудиторию, а тренды digital-маркетинга покоряются легко, как асаны в йоге! Желаем, чтобы каждый день радовал креативом, чашечкой ароматного кофе и новыми горизонтами с друзьями!

Ваш клиентский менеджер
[ФИО менеджера]""",
               """С днём рождения!
Денис Игоревич!

Пусть ваши финансовые стратегии, как шахматные партии, ведут к стабильным победам, а инвестиции приносят уверенность, как плавание — гармонию! Желаем, чтобы классическая мудрость книг и глубина фильмов вдохновляли, а каждый день радовал изысканными блюдами и мудрыми решениями!

Ваш клиентский менеджер
[ФИО менеджера]""",
               """С днём рождения!
Елена Владимировна!

Пусть ваши проекты, как изящные интерьеры, обретают гармонию, а жизнь цветёт ярче садовых композиций! Желаем, чтобы творчество вязало успехи в уютный ковёр, а каждый день радовал семейными прогулками, театральными эмоциями и лёгким намёком на шоколадное настроение!

Ваш клиентский менеджер
[ФИО менеджера]""",
               """С днём рождения!
Олег Тимофеевич!

Пусть ваш код, как эпичные баталии в Dota 2, ведёт к победам, а креативность расцветает ярче палитры комиксов! Желаем, чтобы гибкий график дарил время для настольных сражений с друзьями, а эксперименты на кухне становились сочными, как идеальный бургер!

Ваш клиентский менеджер
[ФИО менеджера]""",
               """С днём рождения!
Виктория Андреевна!

Пусть ваш год танцует в ритме сальсы, наполняется ароматами азиатских специй и солнечными красками путешествий! Желаем, чтобы каждый проект в "FutureTech" становился ярким дуэтом талантов, а тренинги открывали новые горизонты вдохновения!

Ваш клиентский менеджер
[ФИО менеджера]""",
               """С днём рождения!
Артем Павлович!

Пусть ваш "ГурманЪ" дарит гостям вкус побед, как редкие вина — изысканные моменты, а охота за новыми рецептами вдохновляет, как семейные выезды на природу! Желаем, чтобы бизнес цвёл, как идеальное меню, а каждый день наполнялся гармонией работы и теплом близких!

Ваш клиентский менеджер
[ФИО менеджера]"""]

yandex_gpt = ["""С днём рождения, Алексей Сергеевич!

Пусть каждый ваш проект взлетает к новым высотам, как современные технологии к вершинам прогресса, а жизнь будет полна захватывающих открытий и достижений. Желаем, чтобы ваша команда всегда оставалась такой же сплочённой, как ваша семья в путешествиях, а энергия для новых свершений никогда не иссякала!

Ваш клиентский менеджер
[ФИО менеджера]""",
              """С днём рождения, Анна Дмитриевна!

Пусть каждый ваш день будет таким же ярким, как ваши фотоработы, а креативные идеи продолжают вдохновлять коллег и восхищать клиентов. Желаем, чтобы ваши профессиональные проекты набирали миллионы просмотров, а энергия для новых свершений всегда оставалась на максимальном уровне!

Ваш клиентский менеджер
[ФИО менеджера]""",
              """С днём рождения, Денис Игоревич!

Пусть ваши стратегические решения всегда ведут к успеху, а аналитический ум помогает находить самые выгодные возможности для роста. Желаем, чтобы ваши инвестиции приносили стабильный доход, а жизнь была наполнена гармонией и спокойствием, как идеально выстроенная шахматная партия!

Ваш клиентский менеджер
ФИО менеджера""",
              """С днём рождения, Елена Владимировна!

Пусть каждый ваш проект превращается в произведение искусства, а творческий потенциал расцветает, как весенний сад. Желаем, чтобы ваши дизайнерские решения всегда находили идеальный баланс между красотой и функциональностью, а жизнь была наполнена теплом семейного очага и новыми вдохновляющими идеями!

Ваш клиентский менеджер
ФИО менеджера""",
              """С днём рождения, Олег Тимофеевич!

Пусть ваш код всегда будет безупречным, как сюжеты любимых комиксов, а новые проекты приносят не меньше удовольствия, чем победы в киберспортивных турнирах. Желаем, чтобы каждый день был наполнен интересными задачами, а жизнь радовала балансом между захватывающими технологиями и уютными вечерами с друзьями!

Ваш клиентский менеджер
ФИО менеджера""",
              """С днём рождения, Виктория Андреевна!

Пусть ваша жизнь будет такой же яркой, как сальса на танцполе, а каждое утро начинается с новых идей и вдохновения! Желаем, чтобы ваша харизма продолжала объединять людей в сильные команды, а профессиональные достижения шли рука об руку с увлекательными путешествиями и кулинарными открытиями. Пусть каждый день приносит радость от новых знакомств и возможность помогать другим находить свой путь в профессии!

Ваш клиентский менеджер
ФИО менеджера""",
              """С днём рождения, Артем Павлович!

Пусть ваш ресторанный бизнес процветает, как изысканное вино в вашей коллекции, становясь с годами только лучше и ценнее! Желаем, чтобы каждый день приносил новые гастрономические открытия, а ваши рестораны продолжали радовать гостей неповторимым вкусом и душевной атмосферой.

Пусть семейное счастье будет таким же крепким, как ваши деловые решения, а охотничьи и рыболовные приключения добавляют в жизнь острые ощущения и яркие впечатления!

Ваш клиентский менеджер
ФИО менеджера"""]

giga_chat_2 = ["""С Днём Рождения!

Алексей Сергеевич!

Пусть ваши вершины будут покорены новыми достижениями, а каждый день приносит радость от любимых дел. Желаем вдохновения для новых свершений, крепкого здоровья и незабываемых путешествий вместе с близкими людьми!

Ваш клиентский менеджер [ФИО менеджера]""",
               """С Днём Рождения!


Анна Дмитриевна!


Пусть яркие идеи освещают ваш путь, а каждая новая фотография становится шедевром. Желаем успехов во всех начинаниях, вдохновения и самых красивых моментов в жизни!


Ваш клиентский менеджер [ФИО менеджера]""",
               """С Днём Рождения!

Денис Игоревич!

Пусть ваши финансовые горизонты расширяются, а шахматные партии приносят только победы. Желаем стабильности на пути к новым вершинам, ясности мысли и гармонии в каждом дне!

Ваш клиентский менеджер [ФИО менеджера]""",
               """С Днём Рождения!

Елена Владимировна!

Пусть ваше творчество расцветает яркими красками, а дом наполняется теплом и уютом. Желаем вдохновения, семейного счастья и радости от каждого созданного интерьера!

Ваш клиентский менеджер [ФИО менеджера]""",
               """С Днём Рождения!


Олег Тимофеевич!


Пусть ваш код будет безупречен, как победа в турнире, а каждый новый проект открывает перед вами захватывающие возможности. Желаем удачи в играх, интересных задач и наслаждения каждым моментом жизни!


Ваш клиентский менеджер [ФИО менеджера]""",
               """С Днём Рождения!

Виктория Андреевна!

Пусть ваша энергия зажигает сердца коллег, а танцы дарят легкость каждому дню. Желаем тепла, вдохновения и множества возможностей воплотить мечты в реальность!

Ваш клиентский менеджер [ФИО менеджера]""",
               """С Днём Рождения!

Артем Павлович!

Пусть ароматы ваших ресторанов продолжают радовать гурманов, а природа дарит моменты истинной свободы. Желаем благополучия вашему бизнесу, счастья семье и новых открытий в мире вкусов!

Ваш клиентский менеджер [ФИО менеджера]"""]

# %% [markdown]
# ### BLUE

# %% [markdown]
# BLUE (Bilingual Evaluation Understudy) - это метрика, которая используется для оценки качества машинного перевода. Она вычисляется как:
#
# $$
# \text{BLUE} = \exp\left(\min(0, 1 - \frac{r}{c})\right) \cdot \left(\prod_{n=1}^{N}\text{precision}_n\right)^{1/N}
# $$
#
# где:
# - $r$ — количество слов в переводе,
# - $c$ — количество слов в эталонном тексте,
# - $\text{precision}_n$ — точность на уровне n-грамм.

# %%
from nltk.translate.bleu_score import sentence_bleu
import nltk

# %%
import string

def cleaner(x):
    x = x.lower().replace('\n', ' ')
    table = str.maketrans("","", string.punctuation)
    x = x.translate(table)
    x_split = x.split(' ')
    x_split = [x_i for x_i in x_split if x_i]
    return x_split
    # x_clean =

# %% [markdown]
# references -  это исходное предложение, которое используется как эталон для сравнения
#
# candidates = hypothesis - это предложение, которое было получено в результате генерации

# %%
# Рассчитываем BLEU scorae
blue_score = []
for can in [chatgpt, deepseek_v1, giga_chat, giga_chat_2, yandex_gpt]:
    score = 0
    for i in range(7):
        references = list(map(cleaner,  deepseek_r1))
        candidates = list(map(cleaner, can))
        score += sentence_bleu(references = [references[i]],
                               hypothesis = candidates[i])
    print(f'Corpus BLEU score: {score/len(references):.4f}')
    blue_score.append(score/len(references))
# Out:
# Corpus BLEU score: 0.1965
# Corpus BLEU score: 0.2642
# Corpus BLEU score: 0.0837
# Corpus BLEU score: 0.2104
# Corpus BLEU score: 0.1879

# %% [markdown]
# ### **ROUGE**

# %% [markdown]
# ROUGE (Recall-Oriented Understudy for Gisting Evaluation) - это набор метрик, используемых для оценки качества текстовых резюме и машинного перевода. Основная идея заключается в сравнении автоматически сгенерированного текста с эталонным текстом.
#
# - **ROUGE-N**: Оценивает совпадение n-грамм между двумя текстами. Например, ROUGE-1 оценивает однословные совпадения, а ROUGE-2 - двухсловные совпадения.
# - **ROUGE-L**: Основан на длине наибольшего общего подсписка (LCS).
# - **ROUGE-S**: Основан на skip-bigrams.
#
# Формулы для каждой из этих метрик выглядят следующим образом:
#
# **ROUGE-N:**
#
# $$ \text{ROUGE-N} = \frac{\sum_{S \in \text{RS}} \sum_{\text{n-gram} \in S} \text{Count}_{\text{match}}(\text{n-gram})}{\sum_{S \in \text{RS}} \sum_{\text{n-gram} \in S} \text{Count}(\text{n-gram})} $$
#
# где RS - множество эталонных текстов, Count_match(n-gram) - количество совпадающих n-грамм между автоматически сгенерированным текстом и эталоном, а Count(n-gram) - общее количество n-грамм в эталоне.
#
# **ROUGE-L:**
#
# $$ \text{ROUGE-L} = \frac{(1 + \beta^2) \cdot P_r \cdot R_r}{R_r + \beta^2 \cdot P_r} $$
#
# где $P_r$ - точность (precision), $R_r$ - полнота (recall), $\beta$ - коэффициент, который контролирует баланс между точностью и полнотой.
#
# **ROUGE-S:**
#
# $$ \text{ROUGE-S} = \frac{\sum_{S \in \text{RS}} \sum_{\text{skipped bigram} \in S} \text{Count}_{\text{match}}(\text{skipped bigram})}{\sum_{S \in \text{RS}} \sum_{\text{skipped bigram} \in S} \text{Count}(\text{skipped bigram})} $$
#
# где skipped bigram - это пара слов, которые могут быть разделены другими словами, но все еще считаются связанными.

# %%
from rouge_score import rouge_scorer

# %%
class CastomTokenizer:
    def tokenize(self, text):
        return cleaner(text)

# %%
scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=False, tokenizer = CastomTokenizer())


rouge1_score = []
rougeL_score = []
for can in [chatgpt, deepseek_v1, giga_chat, giga_chat_2, yandex_gpt]:

    rouge1 = 0
    rougeL = 0
    ref = deepseek_r1
    for c, r in zip(can, ref):
        scores_2 = scorer.score(target = r,
                                prediction = c)
        rouge1 += scores_2['rouge1'].fmeasure
        rougeL += scores_2['rougeL'].fmeasure

    print('F1-score ROUGE')
    print(f'Total rouge1: {rouge1/len(references):.4f}')
    print(f'Total rougeL: {rougeL/len(references):.4f}')

    rouge1_score.append(rouge1/len(references))
    rougeL_score.append(rougeL/len(references))
# Out:
# F1-score ROUGE
# Total rouge1: 0.4029
# Total rougeL: 0.3675
# F1-score ROUGE
# Total rouge1: 0.4666
# Total rougeL: 0.4199
# F1-score ROUGE
# Total rouge1: 0.3504
# Total rougeL: 0.2954
# F1-score ROUGE
# Total rouge1: 0.4304
# Total rougeL: 0.3936
# F1-score ROUGE
# Total rouge1: 0.4156
# Total rougeL: 0.3437

# %% [markdown]
# ### METEOR

# %% [markdown]
# $$ \text{METEOR} = F_{\text{mean}} \cdot (1 - \gamma \cdot p)^\beta $$
#
# где:
# - $F_{\text{mean}}$ — среднее гармоническое между точностью и полнотой.
# - $\gamma$ — коэффициент, определяющий важность точности по сравнению с полнотой.
# - $p$ — доля лишних слов в ответе.
# - $\beta$ — параметр, регулирующий влияние доли лишних слов на итоговую оценку.
#
# **Описание:**
#
# Метрика **METEOR** (Metric for Evaluation of Translation with Explicit ORdering) используется для оценки качества машинного перевода. Она учитывает не только точность и полноту ответа, но также его структуру и порядок слов. Формула включает три основных компонента:
#
# 1. **Среднее гармоническое между точностью и полнотой ($F_{\text{mean}}$):**
#    Это стандартная мера, которая сочетает в себе точность (доля правильных слов среди всех предсказанных) и полноту (доля правильных слов среди всех ожидаемых).
#
# 2. **Коэффициент важности точности ($\gamma$):**
#    Этот параметр позволяет регулировать вес точности относительно полноты. Обычно он устанавливается равным 0.5, что означает одинаковую важность обоих показателей.
#
# 3. **Доля лишних слов в ответе ($p$):**
#    Эта величина показывает, насколько ответ перегружен лишними словами, которые не присутствуют в эталонном тексте.
#
# 4. **Параметр влияния доли лишних слов ($\beta$):**
#    Этот параметр регулирует степень воздействия доли лишних слов на итоговый результат. Чем больше значение $\beta$, тем сильнее влияние лишних слов на снижение оценки.
#
# Таким образом, формула **METEOR** позволяет учитывать как качество перевода, так и его структурную близость к оригиналу, что делает её более точной и полезной для оценки результатов машинного обучения.

# %%
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.stem.snowball import SnowballStemmer

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
stemmer = SnowballStemmer("russian")
# Out:
# [nltk_data] Downloading package punkt to /Users/egorbykov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/egorbykov/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/egorbykov/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def cleaner_stemmer(text):
    return list(stemmer.stem(word) for word in cleaner(text))

# %%
' '.join(cleaner_stemmer("Пусть каждый день приносит вам радость, новые возможности и вдохновение для достижений. Желаем благополучия, уверенности и ярких успехов!"))
# Out:
# 'пуст кажд ден принос вам радост нов возможн и вдохновен для достижен жела благополуч уверен и ярк успех'

# %%
score_meteor = []
for can in [chatgpt, deepseek_v1, giga_chat, giga_chat_2, yandex_gpt]:

    references = deepseek_r1
    candidates = can
    score = 0
    for i in range(len(references)):
        score += meteor_score([cleaner_stemmer(references[i])],
                              cleaner_stemmer(candidates[i]))
    print(f'Corpus METEOR score: {score/len(references):.4f}')
    score_meteor.append(score/len(references))
# Out:
# Corpus METEOR score: 0.4334
# Corpus METEOR score: 0.5202
# Corpus METEOR score: 0.3161
# Corpus METEOR score: 0.4331
# Corpus METEOR score: 0.4840

# %%
# метрика после стеминга
score_meteor = []
for can in [chatgpt, deepseek_v1, giga_chat, giga_chat_2, yandex_gpt]:

    references = deepseek_r1
    candidates = can
    score = 0
    for i in range(len(references)):
        score += meteor_score([cleaner_stemmer(references[i])],
                              cleaner_stemmer(candidates[i]))
    print(f'Corpus METEOR score: {score/len(references):.4f}')
    score_meteor.append(score/len(references))
# Out:
# Corpus METEOR score: 0.4334
# Corpus METEOR score: 0.5202
# Corpus METEOR score: 0.3161
# Corpus METEOR score: 0.4331
# Corpus METEOR score: 0.4840

# %% [markdown]
# ### BERTScore

# %% [markdown]
# BERTScore - это метрика оценки качества перевода или генерации текста на основе модели BERT. Она использует контекстные представления слов из модели BERT для сравнения двух текстов. Метрика учитывает как точность (precision), так и полноту (recall) при оценке совпадений между двумя текстами.
#
# Формула для вычисления BERTScore выглядит следующим образом:
#
# $$
# \text{BERTScore} = \frac{\sum_{i=1}^{n} \text{IDF}(w_i) * \text{Precision}(w_i) * \text{Recall}(w_i)}{\sum_{i=1}^{n} \text{IDF}(w_i)}
# $$
#
# где:
# - $w_i$ - i-й токен,
# - $\text{IDF}(w_i)$ - обратная частота документа для токена $w_i$,
# - $\text{Precision}(w_i)$ - точность для токена $w_i$,
# - $\text{Recall}(w_i)$ - полнота для токена $w_i$.
#
# Точность и полнота определяются как:
#
# $$
# \text{Precision}(w_i) = \frac{\text{CosSim}(\mathbf{h}_{w_i}, \mathbf{r}_j)}{\max_k(\text{CosSim}(\mathbf{h}_{w_i}, \mathbf{r}_k))}
# $$
#
# $$
# \text{Recall}(w_i) = \frac{\text{CosSim}(\mathbf{h}_{w_i}, \mathbf{r}_j)}{\max_l(\text{CosSim}(\mathbf{h}_{w_l}, \mathbf{r}_j))}
# $$
#
# где:
# - $\mathbf{h}_{w_i}$ - представление слова $w_i$ в гипотезе,
# - $\mathbf{r}_j$ - представление слова $r_j$ в референсе,
# - $\text{CosSim}$ - косинусное сходство между векторами представлений слов.
#
# Таким образом, BERTScore оценивает качество перевода или генерации текста, учитывая семантическое соответствие между словами в контексте обоих текстов.

# %%
from evaluate import load
bertscore = load("bertscore")

# %%
import numpy as np

# %%
score_bert = []
ref = deepseek_r1
for can in [chatgpt, deepseek_v1, giga_chat, giga_chat_2, yandex_gpt]:
    score_bert_mean = 0
    f_score_bert = bertscore.compute(predictions=can, references=ref, lang="ru")['f1']
    print(f'Corpus BERT score: {np.mean(f_score_bert):.4}')
    score_bert.append(np.mean(f_score_bert))
# Out:
# Corpus BERT score: 0.7859
# Corpus BERT score: 0.79
# Corpus BERT score: 0.7522
# Corpus BERT score: 0.771
# Corpus BERT score: 0.7838

# %% [markdown]
# ### Визуал

# %%
# blue_score, rouge1_score, rougeL_score, score_meteor, score_bert

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
models = ['chatgpt', 'deepseek_v1', 'giga_chat', 'giga_chat_2', 'yandex_gpt']

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Ширина столбцов
bar_width = 0.15

# Позиции для каждого столбца
index = np.arange(len(models))

# Добавляем столбцы для каждой метрики
ax.bar(index - 2*bar_width, blue_score, bar_width, label='blue_score', color='blue')
ax.bar(index - bar_width, rouge1_score, bar_width, label='rouge1_score', color='green')
ax.bar(index, rougeL_score, bar_width, label='rougeL_score', color='red')
ax.bar(index + bar_width, score_meteor, bar_width, label='score_meteor', color='purple')
ax.bar(index + 2*bar_width, score_bert, bar_width, label='score_bert', color='orange')

# Настройка
ax.set_xlabel('Модели')
ax.set_ylabel('Значения метрик')
ax.set_title('Сравнение генерации поздравления для различных моделей')
ax.set_xticks(index)
ax.set_xticklabels(models)
ax.legend()

plt.tight_layout()
plt.show()

# %%
metrics = ['blue_score', 'rouge1_score', 'rougeL_score', 'score_meteor', 'score_bert']
fig, ax = plt.subplots(figsize=(10, 6))

# Ширина столбцов
bar_width = 0.15

# Позиции для каждого столбца
index = np.arange(len(models))

# Добавляем столбцы для каждой метрики
ax.bar(index - 2*bar_width, [blue_score[0],rouge1_score[0],rougeL_score[0],score_meteor[0],score_bert[0]], bar_width, label='chatgpt', color='blue')
ax.bar(index - bar_width, [blue_score[1],rouge1_score[1],rougeL_score[1],score_meteor[1],score_bert[1]], bar_width, label='deepseek_v1', color='green')
ax.bar(index,[blue_score[2],rouge1_score[2],rougeL_score[2],score_meteor[2],score_bert[2]], bar_width, label='giga_chat', color='red')
ax.bar(index + bar_width, [blue_score[3],rouge1_score[3],rougeL_score[3],score_meteor[3],score_bert[3]], bar_width, label='giga_chat_2', color='purple')
ax.bar(index + 2*bar_width,[blue_score[4],rouge1_score[4],rougeL_score[4],score_meteor[4],score_bert[4]], bar_width, label='yandex_gpt', color='orange')

# Настройка
ax.set_xlabel('Модели')
ax.set_ylabel('Значения метрик')
ax.set_title('Сравнение генерации поздравления для различных моделей')
ax.set_xticks(index)
ax.set_xticklabels(metrics)
ax.legend()

plt.tight_layout()
plt.show()
